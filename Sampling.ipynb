# %% [markdown]
# <a href="https://colab.research.google.com/github/Ishanavi/Sampling/blob/main/Sampling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
data_upload = files.upload()
# Out:
#      <input type="file" id="files-2ca2c7bb-a351-405f-94d6-860e6e887512" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2ca2c7bb-a351-405f-94d6-860e6e887512">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving datanew.csv to datanew.csv

# %%
import pandas as pd
import statistics
import random
import plotly.figure_factory as ff
import plotly.graph_objects as go
import csv

df = pd.read_csv("datanew.csv")
data_list = df["temp"].tolist()

fig = ff.create_distplot(
                            [data_list],
                            ["Temperature"],
                            show_hist = False
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
data_set = []
for i in range(0,100):
  data_index = random.randint(0,len(data_list))
  value = data_list[data_index]
  data_set.append(value)

mean = statistics.mean(data_set)
std_dev = statistics.stdev(data_set)
print("Mean ->", mean)
print("Standard Deviation ->" , std_dev)
# Out:
# Mean -> 35.25
# Standard Deviation -> 5.878182568024772

# %%
def randomSetOfMean(counter):
  random_data = []

  for i in range(0,counter):
    random_index = random.randint(0,len(data_list))
    value = data_list[random_index]
    random_data.append(value)

  mean = statistics.mean(random_data)
  return mean

# %%
def distPlotFunc(mean_list):
  fig = ff.create_distplot(
                            [mean_list],
                            ["Temperature"],
                            show_hist = False
  )

  fig.show()

# %%
def setup():
  mean_list = []

  for i in range(0,1000):
    set_of_mean = randomSetOfMean(100)
    mean_list.append(set_of_mean)

  distPlotFunc(mean_list)

setup()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
def stdDeviation():
  mean_list = []

  for i in range(0,1000):
    set_of_mean = randomSetOfMean(100)
    mean_list.append(set_of_mean)

  std_dev = statistics.stdev(mean_list)
  print("Standard Deviation ->", std_dev)

stdDeviation()
# Out:
# Standard Deviation -> 0.5798847242283535
